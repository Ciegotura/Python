# %% [markdown]
# # Analiza danych przestrzennych - ćwiczenia laboratoryjne 2022/2023
#
# Ten notatnik zalicza się do grupy zestawów zadań, na podstawie których odbywa się zaliczenie ćwiczeń i podlega zwrotowi do oceny w ustalonym na zajęciach terminie.
#
# Uwagi ogólne:
# - Podczas wykonywania zadań należy korzystać wyłącznie z pakietów zaimportowanych na początku notatnika oraz z pakietów wchodzących w skład standardowej biblioteki Pythona, które można zaimportować samodzielnie we wskazanej komórce.
# - Swoje rozwiązania należy wprowadzać wyłącznie w miejce następujących fragmentów kodu:<br/> ` # YOUR CODE HERE`<br/> ` raise NotImplementedError()`<br/> Nie należy w żaden sposób modyfikować pozostałych fragmentów kodu oraz elementów notatnika, w szczególności dodawać lub usuwać komórek oraz zmieniać nazwy pliku.
# - Jeżeli zestaw zadań wymaga skorzystania z funkcji przygotowanych w ramach wcześniejszych zestawów zadań należy je umieścić we wskazanej komórce.
# - Wszystkie wykresy powinny być wykonane w jednolitym, przejrzystym i czytelnym stylu, mieć nadane tytuły, opisane osie oraz odpowiednio dobrany rozmiar, wielkość punktów i grubość linii. Proporcje osi wykresów przedstawiających rozkłady punktów powinny być dobrane tak, aby wykresy odzwierciedlały rzeczywisty rozkład punktów w przestrzeni.
# - Zadania, które powodują wyświetlenie komunikatu o błędzie przerywającym wykonywanie kodu nie podlegają ocenie.
#
# Przed odesłaniem zestawu zadań do oceny proszę uzupełnić komórkę z danymi autorów rozwiązania (`NAME` - nazwa grupy, `COLLABORATORS` - imiona, nazwiska i numery indeksów członków grupy) oraz upewnić się, że notatnik działa zgodnie z oczekiwaniami. W tym celu należy skorzystać z opcji **Restart Kernel and Run All Cells...** dostępnej na górnej belce notatnika pod symbolem $\blacktriangleright\blacktriangleright$.

# %%
NAME = "Piotr Cięgotura, Wojciech Sutowicz, Brunon Kania, Filip Magnowski"
#COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# ## Zestaw zadań 7: Analiza danych przestrzennych z wykorzystaniem pakietów GeoPandas i PySAL (część 1)

# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
# Miejsce do importu pakietów wchodzących w skład standardowej biblioteki Pythona oraz ustawienie opcji wykorzystywanych pakietów

# %%
# Miejsce do wklejenie funkcji ze wcześniejszych zestawów zadań
# YOUR CODE HERE
#raise NotImplementedError()

# %% [markdown]
# ### Zadanie 1: Import i przygotowanie danych (9 pkt)
#
# Wykorzystując funkcję `geopandas.read_file()` zaimportuj do notatnika dane z trzech dołączonych do niego plików. Następnie, wykorzystując funkcję `geopandas.GeoDataFrame()` przygotuj na ich podstawie trzy tablice z danymi:
#
# 1) Tablica zawierająca wybrane dane dotyczące województw:
#     - "Nazwa" - nazwy województw
#     - "geometry" - geometria obiektów
# <br/>
# <br/>
# 2) Tablica zawierającąa wybrane dane dotyczące <u>miast</u>:
#     - "Nazwa" - nazwy miast
#     - "geometry" - geometria obiektów
# <br/>
# <br/>
# 2) Tablica zawierająca wybrane dane dotyczące <u>Wisły</u> i <u>Odry</u>:
#     - "Nazwa" - nazwy rzek
#     - "geometry" - geometria obiektów
#
#
# Wyświetl przygotowane tablice.
#
# Uwaga 1: Pliki zawierają więcej danych niż opisane wyżej tablice. W wynikowych tablicach nie powinny znaleźć się zbędne dane.
#
# Uwaga 2: Poprawny import polskich nazw może wymagać ustawienia odpowiedniej wartości argumentu `encoding` podczas wywoływania funkcji `geopandas.read_file()`.

# %%
# Województwa
# YOUR CODE HERE


woje = gpd.read_file("Wojewodztwa.zip")

wojew = {'Nazwa': woje["JPT_NAZWA_"], 'geometry': woje["geometry"]}
woj1 = gpd.GeoDataFrame(wojew)

woj1

#d1 = gpd.read_file("Wojewodztwa.zip")
#wojew = {'Nazwa': d1["JPT_Nazwa_"], 'geometry': d1["geometry"]}
#gdf1 = gpd.GeoDataFrame(data1)


#raise NotImplementedError()
#print(woj1['geometry'][10])
#s=woj1['geometry'][10]
#s=s.bounds
#print(s) #zwraca minx, miny, maxx, maxy
#print(woj1['geometry'][12])
#print(woj1)
# Out:
#                   Nazwa                                           geometry
# 0               śląskie  MULTIPOLYGON (((18.91685 51.09608, 18.91677 51...
# 1              opolskie  POLYGON ((17.81203 51.18669, 17.81209 51.18670...
# 2        świętokrzyskie  POLYGON ((19.70430 50.75239, 19.70443 50.75248...
# 3             pomorskie  POLYGON ((17.66483 54.78297, 17.66653 54.78334...
# 4             podlaskie  POLYGON ((21.98108 52.97859, 21.98078 52.97861...
# 5    zachodniopomorskie  POLYGON ((14.81157 54.04037, 14.89525 54.05570...
# 6          dolnośląskie  POLYGON ((15.10534 51.42730, 15.10540 51.42732...
# 7         wielkopolskie  POLYGON ((16.71447 53.29913, 16.71447 53.29920...
# 8          podkarpackie  POLYGON ((22.03538 50.80675, 22.03550 50.80681...
# 9           małopolskie  POLYGON ((19.97230 50.51625, 19.97227 50.51633...
# 10  warmińsko-mazurskie  POLYGON ((21.55932 54.32250, 21.55939 54.32250...
# 11              łódzkie  POLYGON ((19.99385 51.18395, 19.99410 51.18395...
# 12          mazowieckie  POLYGON ((21.98576 52.97722, 21.98587 52.97708...
# 13   kujawsko-pomorskie  POLYGON ((17.65670 53.57115, 17.65672 53.57115...
# 14            lubelskie  POLYGON ((21.61554 51.61756, 21.62194 51.62192...
# 15             lubuskie  POLYGON ((15.10534 51.42730, 15.10521 51.42727...

# %%
# Miasta
# YOUR CODE HERE

miejsc = gpd.read_file("Miejscowosci.zip")
print(miejsc)
miejsc = miejsc[(miejsc.rodzaj == "miasto")]
print(miejsc)
miejsca = {'Nazwa': miejsc["nazwaGlown"], 'geometry': miejsc["geometry"]}
mie2 = gpd.GeoDataFrame(miejsca)

mie2
#miejsca= gpd.GeoDataFrame(miejsc, columns=['NAZWA', 'geometry'])
#miejsc


#raise NotImplementedError()
# Out:
#                            idIIP        nazwaGlown    kategoria  \
# 0            PL.PZGiK.320.NGRP.2    Osiedle Struga  miejscowość
# 1            PL.PZGiK.320.NGRP.4          Abisynia  miejscowość
# 2            PL.PZGiK.320.NGRP.6          Abisynia  miejscowość
# 3            PL.PZGiK.320.NGRP.7          Abisynia  miejscowość
# 4            PL.PZGiK.320.NGRP.8          Abisynia  miejscowość
# ...                          ...               ...          ...
# 124667  PL.PZGiK.320.NGRP.269307         Na Debrzy  miejscowość
# 124668  PL.PZGiK.320.NGRP.269308             Ulica  miejscowość
# 124669  PL.PZGiK.320.NGRP.269309        Zbydniówki  miejscowość
# 124670  PL.PZGiK.320.NGRP.269327  Kolonia Łeszczyn  miejscowość
# 124671  PL.PZGiK.320.NGRP.269328         Partykowo  miejscowość
#
#                 rodzaj                       geometry
# 0         część miasta  POINT (334530.330 319384.250)
# 1            część wsi  POINT (419019.650 447421.450)
# 2       przysiółek wsi  POINT (274559.800 556336.000)
# 3            część wsi  POINT (300270.010 557521.480)
# 4         część miasta  POINT (427022.520 292751.830)
# ...                ...                            ...
# 124667       część wsi  POINT (566665.720 228636.620)
# 124668       część wsi  POINT (567546.980 232975.410)
# 124669    część miasta  POINT (568842.720 233902.550)
# 124670         kolonia  POINT (477079.070 391327.260)
# 124671       część wsi  POINT (549194.420 211597.070)
#
# [124672 rows x 5 columns]
#                            idIIP            nazwaGlown    kategoria  rodzaj  \
# 325        PL.PZGiK.320.NGRP.402  Aleksandrów Kujawski  miejscowość  miasto
# 326        PL.PZGiK.320.NGRP.403    Aleksandrów Łódzki  miejscowość  miasto
# 390        PL.PZGiK.320.NGRP.483              Alwernia  miejscowość  miasto
# 447        PL.PZGiK.320.NGRP.570             Andrychów  miejscowość  miasto
# 580        PL.PZGiK.320.NGRP.741               Annopol  miejscowość  miasto
# ...                          ...                   ...          ...     ...
# 101357  PL.PZGiK.320.NGRP.164350               Żuromin  miejscowość  miasto
# 101387  PL.PZGiK.320.NGRP.164412               Żychlin  miejscowość  miasto
# 101460  PL.PZGiK.320.NGRP.164568              Żyrardów  miejscowość  miasto
# 101497  PL.PZGiK.320.NGRP.164618                Żywiec  miejscowość  miasto
# 101931  PL.PZGiK.320.NGRP.168371                  Brok  miejscowość  miasto
#
#                              geometry
# 325     POINT (479373.050 556833.540)
# 326     POINT (520933.510 439274.230)
# 390     POINT (538609.780 243752.610)
# 447     POINT (524250.260 220924.610)
# 580     POINT (700882.160 339274.920)
# ...                               ...
# 101357  POINT (561072.600 578091.430)
# 101387  POINT (542758.370 486616.290)
# 101460  POINT (599274.600 466617.820)
# 101497  POINT (513848.050 201968.410)
# 101931  POINT (693022.080 540797.530)
#
# [964 rows x 5 columns]
#                        Nazwa                       geometry
# 325     Aleksandrów Kujawski  POINT (479373.050 556833.540)
# 326       Aleksandrów Łódzki  POINT (520933.510 439274.230)
# 390                 Alwernia  POINT (538609.780 243752.610)
# 447                Andrychów  POINT (524250.260 220924.610)
# 580                  Annopol  POINT (700882.160 339274.920)
# ...                      ...                            ...
# 101357               Żuromin  POINT (561072.600 578091.430)
# 101387               Żychlin  POINT (542758.370 486616.290)
# 101460              Żyrardów  POINT (599274.600 466617.820)
# 101497                Żywiec  POINT (513848.050 201968.410)
# 101931                  Brok  POINT (693022.080 540797.530)
#
# [964 rows x 2 columns]

# %%
# Rzeki
# YOUR CODE HERE


rzeczki = gpd.read_file("Rzeki.zip")

rzeczka= {'Nazwa': rzeczki["NAZ_RZEKI"], 'geometry': rzeczki["geometry"]}
rzecz3 = gpd.GeoDataFrame(rzeczka)

rzecz3_ODRA = rzecz3[(rzecz3.Nazwa == "Odra")]
rzecz3_WISLA = rzecz3[(rzecz3.Nazwa == "Wisła")]

rzecz3_2 = pd.concat([rzecz3_ODRA, rzecz3_WISLA])
print(rzecz3_2)
#rzeki = gpd.GeoDataFrame(rzecz3_ODRA,rzecz3_WISLA)

#rzeki = gpd.GeoDataFrame(rzeczki, columns=['NAZWA', 'geometry'])

#raise NotImplementedError()
# Out:
#    Nazwa                                           geometry
# 0   Odra  MULTILINESTRING ((17.52056 49.61373, 17.52159 ...
# 1  Wisła  MULTILINESTRING ((19.00368 49.60595, 19.00338 ...

# %% [markdown]
# ### Zadanie 2: Transformacja między odwzorowaniami kartograficznymi (3 pkt)
#
# Wczytywane dane są zapisane z wykorzystaniem różnych odwzorowań kartograficznych. Przed rozpoczęciem analizy należy je ze sobą uzgodnić.
#
# Korzystając z własności obiektów GeoDataFrame `geopandas.GeoDataFrame.crs` sprawdzć odwzorowanie kartograficzne, w którym zapisane są poszczególne tablice. Jeżeli odwzorowanie jest inne niż epsg:2180 dokonaj jego konwersji z wykorzystaniem funkcji `geopandas.GeoDataFrame.to_crs()`.

# %%
# YOUR CODE HERE
#woj1 = woj1.to_crs({'init': 'epsg:2180'})
#rzecz3_2 = rzecz3_2.to_crs({'init': 'epsg:2180'})
#mie2 = mie2.to_crs({'init': 'epsg:2180'})
woj1.crs
woj1 = woj1.to_crs('2180')

rzecz3_2.crs
rzecz3_2 = rzecz3_2.to_crs('2180')
rzecz3.crs
rzecz3=rzecz3.to_crs('2180')
mie2.crs
mie2 = mie2.to_crs('2180')
#woje.crs  #rzeki sa w dobrym ukladzie

#rzeki = rzeki.to_crs('2180')
#rzeki.crs
#raise NotImplementedError()

# %% [markdown]
# ### Zadanie 3: Wizualizacja danych wejściowych (3 pkt)
#
# Korzystając z funkcji pakietu matplotlib oraz funkcji `geopandas.GeoDataFrame.plot()` zwizualizuj komplet przygotowanych danych. Ustaw parametry wykresu oraz wizualizowanych obiektów (wielkość figury, kolory, grubość linii, wielkość punktów itp.) tak aby wygenerowana mapa była przejrzysta i czytelna.

# %%
# YOUR CODE HERE

ax1 = woj1.plot(color = "green", figsize = [18,20], edgecolor='black')

mie2.plot(ax = ax1, color = "orange", markersize = 20)

rzecz3_2.plot(ax = ax1, color="blue")

#raise NotImplementedError()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Zadanie 4: Mierzenie długości, pola powierzchni i odległości (10 pkt)

# %% [markdown]
# #### a) Długość Wisły
# Korzystając z własności `geopandas.GeoSeries.length` zmierz długość Wisły. Wyświetl odpowiedź podając długość rzeki w kilometrach.

# %%
# YOUR CODE HERE

rzecz3_WISLA = rzecz3_WISLA.to_crs('2180')

s=rzecz3_WISLA.geometry.length / 10**3
print("Długość Wisły wynosi: {} km".format(s[1]))

#print('Odległość Poznania od Krakowa wynosi', dl_wisla)
#rzecz3_WISLA['geometry'].length
#raise NotImplementedError()
# Out:
# Długość Wisły wynosi: 1019.7577991167121 km

# %% [markdown]
# #### b) Pola powierzchni województw
# Korzystając z własności `geopandas.GeoSeries.area` zmierz powierzchnię województw. Zapisz wyniki do tablicy w kolumnie o nazwie "Pole".
# Następnie wykorzystaj dane do odpowiedzenia na pytanie jakie jest pole powierzchni Polski (podaj pole w kilometrach kwadratowych) oraz przygotowania wizualiacji, na której kolor przypisany województwom jest powiązany z ich powierzchnią. Ustaw parametry wykresu oraz wizualizowanych obiektów (wielkość figury, kolory, grubość linii, wielkość punktów itp.) tak aby wygenerowana mapa była przejrzysta i czytelna.

# %%
# Obliczenia
# YOUR CODE HERE
#rzecz3_WISLA = rzecz3_WISLA.to_crs('2180')
#rzecz3_WISLA["area"] = rzecz3_WISLA['geometry'].area/ 10**6


#woj1 = woj1['geometry'].to_crs({'proj':'cea'}) 

woj1['pole'] = woj1.area / 10**6

woj_pole = woj1['pole'].sum()
print("Pole powierzchni Polski wynosi: {} km".format(woj_pole))

woj_pole

#also need to divide by 1000000 zeby dostac wartosc w km2
#raise NotImplementedError()
# Out:
# Pole powierzchni Polski wynosi: 4.1051711347826445e-05 km
# C:\Users\Ja\AppData\Local\Temp\ipykernel_10884\1965478866.py:9: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   woj1['pole'] = woj1.area / 10**6
# 4.1051711347826445e-05

# %%
# Wizualizacja
# YOUR CODE HERE

ax1 = woj1.plot(column = 'pole', figsize = [18,20], edgecolor='black')
plt.title("Pola powierzchni województw")
#raise NotImplementedError()
# Out:
# Text(0.5, 1.0, 'Pola powierzchni województw')

# %% [markdown]
# #### c) Odległość miast od Krakowa
# Korzystając z funkcji `geopandas.GeoSeries.distance()` zmierz odległość poszczególnych miast od Krakowa. Zapisz wyniki do tablicy w kolumnie o nazwie "Odległość od Krakowa".
# Następnie wykorzystaj dane do odpowiedzenia na pytanie w jakiej odległości od Krakowa leży Poznań (odpowiedź podaj w kilometrach) oraz przygotowania wizualiacji, na której kolor przypisany miastom jest powiązany z ich odległością od Krakowa.
#
# Wizualizacja powinna zawierać:
# - kontury województw, bez wypełnienia,
# - lokalicaje miast.
#
# Ustaw parametry wykresu oraz wizualizowanych obiektów (wielkość figury, kolory, grubość linii, wielkość punktów itp.) tak aby wygenerowana mapa była przejrzysta i czytelna.

# %%
# Obliczenia
# YOUR CODE HERE
#mie2[
mie2['Odległość od Krakowa'] = mie2.geometry.distance(mie2.geometry[mie2['Nazwa'] == 'Kraków'][37334]) / 10**3

mie2[mie2['Nazwa'] == 'Poznań']

print('Odległość Poznania od Krakowa wynosi', mie2[mie2['Nazwa'] == 'Poznań']['Odległość od Krakowa'][66964])
print(mie2['geometry'][37334])
mie2
#raise NotImplementedError()
# Out:
# Odległość Poznania od Krakowa wynosi 334.60495145299524
# POINT (567071.76 244256.23)
#                        Nazwa                       geometry  \
# 325     Aleksandrów Kujawski  POINT (479373.050 556833.540)
# 326       Aleksandrów Łódzki  POINT (520933.510 439274.230)
# 390                 Alwernia  POINT (538609.780 243752.610)
# 447                Andrychów  POINT (524250.260 220924.610)
# 580                  Annopol  POINT (700882.160 339274.920)
# ...                      ...                            ...
# 101357               Żuromin  POINT (561072.600 578091.430)
# 101387               Żychlin  POINT (542758.370 486616.290)
# 101460              Żyrardów  POINT (599274.600 466617.820)
# 101497                Żywiec  POINT (513848.050 201968.410)
# 101931                  Brok  POINT (693022.080 540797.530)
#
#         Odległość od Krakowa
# 325               324.646944
# 326               200.401493
# 390                28.466435
# 447                48.765206
# 580               164.115126
# ...                      ...
# 101357            333.889099
# 101387            243.576558
# 101460            224.681329
# 101497             67.978107
# 101931            322.180424
#
# [964 rows x 3 columns]

# %%
# Wizualizacja
# YOUR CODE HERE

fig, ax = plt.subplots(figsize=(10, 10))
woj1.plot(ax=ax, color="none", edgecolor="k", linewidth=1)
mie2.plot(ax=ax, column="Odległość od Krakowa", cmap="plasma", markersize=10)
#raise NotImplementedError()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Zadanie 5: Wykorzystanie prostych operacji geometrycznych (12 pkt)

# %% [markdown]
# #### a) Miasta blisko Wisły
#
# Korzystając z funkcji `geopandas.GeoSeries.buffer()` oraz `geopandas.GeoSeries.within()` sprawdź, które miast leżą bliżej niż 20 km od Wisły. Zapisz wyniki do tablicy w kolumnie o nazwie "Blisko Wisły".
# Następnie wykorzystaj dane do odpowiedzenia na pytanie ile miast leży bliżej niż 20 km od Wisły oraz przygotowania wizualiacji, na której oznaczony zostanie obszar znajdujący się bliżej niż 20 km od Wisły, a znajdujące się w tym obszarze miasta będą wyróżnione kolorem względem pozostałych miast.
#
# Wizualizacja powinna zawierać:
# - województwa, wypełnione jednolitym kolorem,
# - miasta, w jednym z dwóch wybranych kolorów w zależności od położenia w obrębie lub poza analizowanym obszarem.
# - rzeki wypełnione jednolitym kolorem,
# - oznaczenie obszaru leżącego nie dalej niż 20 km od Wisły.
#
# Ustaw parametry wykresu oraz wizualizowanych obiektów (wielkość figury, kolory, grubość linii, wielkość punktów itp.) tak aby wygenerowana mapa była przejrzysta i czytelna.

# %%
# Obliczenia
# YOUR CODE HERE
#raise NotImplementedError()
bufor = rzecz3_WISLA.buffer(20000)
mie2['Blisko Wisły'] = mie2.within(bufor[1])
print("Ilość miast leżących bliżej niż 20 km od Wisły: {} km".format(sum(mie2['Blisko Wisły'])))
mie2
# Out:
# Ilość miast leżących bliżej niż 20 km od Wisły: 148 km
#                        Nazwa                       geometry  \
# 325     Aleksandrów Kujawski  POINT (479373.050 556833.540)
# 326       Aleksandrów Łódzki  POINT (520933.510 439274.230)
# 390                 Alwernia  POINT (538609.780 243752.610)
# 447                Andrychów  POINT (524250.260 220924.610)
# 580                  Annopol  POINT (700882.160 339274.920)
# ...                      ...                            ...
# 101357               Żuromin  POINT (561072.600 578091.430)
# 101387               Żychlin  POINT (542758.370 486616.290)
# 101460              Żyrardów  POINT (599274.600 466617.820)
# 101497                Żywiec  POINT (513848.050 201968.410)
# 101931                  Brok  POINT (693022.080 540797.530)
#
#         Odległość od Krakowa  Blisko Wisły
# 325               324.646944          True
# 326               200.401493         False
# 390                28.466435          True
# 447                48.765206          True
# 580               164.115126          True
# ...                      ...           ...
# 101357            333.889099         False
# 101387            243.576558         False
# 101460            224.681329         False
# 101497             67.978107          True
# 101931            322.180424         False
#
# [964 rows x 4 columns]

# %%
# Wizualizacja
# YOUR CODE HERE
#raise NotImplementedError()
fig, ax = plt.subplots(figsize=(10, 10))
woj1.plot(ax=ax, color="pink", edgecolor="k", linewidth=1)
bufor.plot(ax=ax)
mie2.plot(ax=ax, column="Blisko Wisły", cmap="plasma", markersize=10)
rzecz3.plot(ax=ax, color="blue")
plt.title("Miasta blisko Wisły")
# Out:
# Ilość miast leżących bliżej niż 20 km od Wisły: 148 km
# Text(0.5, 1.0, 'Miasta blisko Wisły')

# %% [markdown]
# #### b) Województwa, przez które przepływa Odra
# Korzystając z funkcji `geopandas.GeoSeries.intersects()` sprawdź, przez które województwa przepływa Odra. Zapisz wyniki do tablicy w kolumnie o nazwie "Odra w obrębie".
# Następnie wykorzystaj dane do odpowiedzenia na pytanie przez ile województw przepływa Odra oraz przygotowania wizualiacji, na której województwa przez które przepływa Odra będą wyróżnione kolorem względem pozostałych województw.
#
# Wizualizacja powinna zawierać:
# - województwa, wwypełnione jednym z dwóch wybranych kolorów w zależności od spełnienia warunku,
# - miasta, wypełnione jednolitym kolorem,
# - rzeki wypełnione jednolitym kolorem.
#
# Ustaw parametry wykresu oraz wizualizowanych obiektów (wielkość figury, kolory, grubość linii, wielkość punktów itp.) tak aby wygenerowana mapa była przejrzysta i czytelna.

# %%
# Obliczenia
# YOUR CODE HERE
rzecz3_ODRA = rzecz3_ODRA.to_crs('2180')
#woj1['Odra w obrębie'] = rzecz3_ODRA.intersects(woj1)
ODRA = rzecz3_ODRA.unary_union
woj1['Odra w obrębie'] = woj1.intersects(ODRA)
woj1
print("Odra przepływa przez: {} wojewudztw".format(sum(woj1['Odra w obrębie'])))
#gpd.overlay(woj1, rzecz3_ODRA, how='intersection')

#woj1[woj1['Odra w obrębie'] == 'True']

#print('Odległość Poznania od Krakowa wynosi', woj1[woj1['Odra w obrębie'] == 'True'])

#raise NotImplementedError()
# Out:
# Odra przepływa przez: 5 wojewudztw

# %%
# Wizualizacja
# YOUR CODE HERE

fig, ax = plt.subplots(figsize=(10, 10))

woj1.plot(ax=ax, column="Odra w obrębie", cmap="plasma", legend = True)
mie2.plot(ax = ax, color = "orange", markersize = 1)
#woj1.plot(ax=ax, color = "pink", edgecolor="k", linewidth=2)

rzecz3_ODRA.plot(ax = ax, color="red")


plt.title("Województwa, przez które przepływa Odra")

#raise NotImplementedError()
# Out:
# Text(0.5, 1.0, 'Województwa, przez które przepływa Odra')

# %% [markdown]
# ### Zadanie 6: Generowanie procesu punktowego w obrębie poligonu (13 pkt)
#
# Przygotuj funkcję `homogeneous_poisson_on_polygon()`, która będzie wykorzystywała funkcję `homogeneous_poisson_on_rectangle()` przygotową w ramach pierwszego zestawu zadań oraz możliwości pakietu geopandas do generowania jednorodnego rozkładu Poissona w obrębie dowolnego poligonu.
#
# Następnie wykorzystaj funkcję do wygenerowania rozkładu punktów o intensywności $10^{-8} pkt/m^2$ na obszarze województwa mazowieckiego i zwizualizuj wyniki. Ustaw parametry wykresu oraz wizualizowanych obiektów (wielkość figury, kolory, grubość linii, wielkość punktów itp.) tak aby wygenerowana mapa była przejrzysta i czytelna.
#
# Przydatne funkcje i własności:
# - `geopandas.GeoSeries.bounds`
# - `geopandas.GeoSeries.from_xy()`
# - `geopandas.GeoSeries.set_crs()`
# - `geopandas.GeoSeries.within()`

# %% [markdown]
# #### a) Przygotowanie funkcji

# %%
def homogeneous_poisson_on_polygon(intensity, polygon):
    """
    Parameters
    -------
    intensity: float
        Liczba dodatnia określająca intensywność procesu punktowego.
    polygon: Polygon
        Obszar, na którym mają zostać wygenerowane punkty.
    
    Returns
    -------
    points: GeoDataFrame
        Tablica zawierająca kolumnę "geometry" ze współrzędnymi punktów w odwzorowaniu kartograficznym identycznym jak odwzorowanie zmiennej polygon.
    """
    # YOUR CODE HERE
    granice=polygon.bounds #zwraca minx, miny, maxx, maxy
    #print(granice)
    x_lim = [granice[0],granice[2]]
    y_lim = [granice[1],granice[3]]
    def homogeneous_poisson_on_rectangle(intensity, x_lim, y_lim):
        """
        Parameters
        -------
        intensity: float
        Liczba dodatnia określająca intensywność procesu punktowego.
        x_lim: list
        Lista określająca zakres wartości współrzędnej X.
        Przykład: [0, 10]
        y_lim: list
        Lista określająca zakres wartości współrzędnej Y.
        Przykład: [0, 10]   
    
        Returns
        -------
        points: DataFrame
        Tablica zawierająca dwie kolumny ze współrzędnymi punktów opisane jako "X" i "Y".
        """
        # YOUR CODE HERE
        #raise NotImplementedError()
        area = (x_lim[1]-x_lim[0])*(y_lim[1]-y_lim[0])
        n = sp.stats.poisson.rvs(intensity*area, size=1)
        x=sp.stats.uniform.rvs(size = n)
        y=sp.stats.uniform.rvs(size = n)
        print(len(x))
        xs = x*(x_lim[1]-x_lim[0])+x_lim[0]
        ys = y*(y_lim[1]-y_lim[0])+y_lim[0]
    
        df=pd.DataFrame()
        df['X']=xs
        df['Y']=ys
        return df
    
    df=homogeneous_poisson_on_rectangle(intensity, x_lim, y_lim)
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.X, df.Y))
    #gdf=gdf.set_crs('epsg:2180')
    #print(dx)
    
    #print(punkty)
    #GeoDataFrame = gpd.GeoDataFrame(punkty)
    #print(gdf)
    
    gdf['W poligonie'] = gdf.within(polygon)
    #gdf=gdf.drop([columns=='X'])
    #gdf = gdf['W poligonie'] == True
    d=0
    #print(gdf['geometry'][4])
    #print("endl")
    #print(gdf)
    for i in range(0,len(gdf)):
        if gdf['W poligonie'][i]==True:
            d=np.append(d,gdf['geometry'][i])
    d=np.delete(d,0)
    gdf = gpd.GeoDataFrame(geometry=d)
    gdf=gdf.set_crs('epsg:2180')
    return gdf
    #raise NotImplementedError()

# %% [markdown]
# #### b) Wygenerowanie procesu

# %%
# YOUR CODE HERE
#raise NotImplementedError()
d=homogeneous_poisson_on_polygon(0.00000008, woj1['geometry'][12])
print(d)
#woj1['geometry'].crs
# Out:
# 0
# Empty GeoDataFrame
# Columns: [geometry]
# Index: []

# %% [markdown]
# #### c) Wizualizacja

# %%
# YOUR CODE HERE
#raise NotImplementedError()
fig, ax = plt.subplots(figsize=(10, 10))
woj1.plot(ax=ax, color="pink", edgecolor="k", linewidth=1)
d.plot(ax=ax, column="geometry", color="green", markersize=1) #cmap="plasma"

Powiaty = gpd.read_file("Powiaty.zip")

granice = Powiaty.dissolve()
granice["Nazwa"][0]="Polska"
print(granice)
d1=homogeneous_poisson_on_polygon(0.00000008, granice['geometry'])
d1.plot(ax=ax, column="geometry", color="green", markersize=1) #cmap="plasma"
# Out:
# C:\Users\Ja\AppData\Local\Programs\Python\Python310\lib\site-packages\geopandas\plotting.py:656: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# C:\Users\Ja\AppData\Local\Temp\ipykernel_8428\3889636227.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   granice["Nazwa"][0]="Polska"
#                                             geometry   Nazwa
# 0  POLYGON ((314574.250 311049.909, 314544.080 31...  Polska
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 12
#      10 granice["Nazwa"][0]="Polska"
#      11 print(granice)
# ---> 12 d1=homogeneous_poisson_on_polygon(0.00000008, granice['geometry'])
#      13 d1.plot(ax=ax, column="geometry", color="green", markersize=1)
#
# Cell In [8], line 18, in homogeneous_poisson_on_polygon(intensity, polygon)
#      16 granice=polygon.bounds #zwraca minx, miny, maxx, maxy
#      17 #print(granice)
# ---> 18 x_lim = [granice[0],granice[2]]
#      19 y_lim = [granice[1],granice[3]]
#      20 def homogeneous_poisson_on_rectangle(intensity, x_lim, y_lim):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 0
